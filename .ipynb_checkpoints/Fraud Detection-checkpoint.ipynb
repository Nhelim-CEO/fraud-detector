# %%
import pandas as pd

print("Project Started")
# Out:
# Project Started

# %%
import pandas as pd

df = pd.read_csv("../data/PS_20174392719_1491204439457_log.csv")

df.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
print("Rows, Columns:", df.shape)

print("\nFraud Count:")
print(df["isFraud"].value_counts())

print("\nTransaction Types:")
print(df["type"].value_counts())
# Out:
# Rows, Columns: (1048575, 11)
#
# Fraud Count:
# isFraud
# 0    1047433
# 1       1142
# Name: count, dtype: int64
#
# Transaction Types:
# type
# CASH_OUT    373641
# PAYMENT     353873
# CASH_IN     227130
# TRANSFER     86753
# DEBIT         7178
# Name: count, dtype: int64

# %%
print(df.shape)
print(df["isFraud"].value_counts())
print(df["type"].value_counts())
# Out:
# (1048575, 11)
# isFraud
# 0    1047433
# 1       1142
# Name: count, dtype: int64
# type
# CASH_OUT    373641
# PAYMENT     353873
# CASH_IN     227130
# TRANSFER     86753
# DEBIT         7178
# Name: count, dtype: int64

# %%
pd.crosstab(df["type"], df["isFraud"])
# Out:
# isFraud        0    1
# type
# CASH_IN   227130    0
# CASH_OUT  373063  578
# DEBIT       7178    0
# PAYMENT   353873    0
# TRANSFER   86189  564

# %%
df[df["isFraud"] == 1].head(20)
# Out:
#       step      type      amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 2        1  TRANSFER      181.00  C1305486145         181.00             0.0
# 3        1  CASH_OUT      181.00   C840083671         181.00             0.0
# 251      1  TRANSFER     2806.00  C1420196421        2806.00             0.0
# 252      1  CASH_OUT     2806.00  C2101527076        2806.00             0.0
# 680      1  TRANSFER    20128.00   C137533655       20128.00             0.0
# 681      1  CASH_OUT    20128.00  C1118430673       20128.00             0.0
# 724      1  CASH_OUT   416001.33   C749981943           0.00             0.0
# 969      1  TRANSFER  1277212.77  C1334405552     1277212.77             0.0
# 970      1  CASH_OUT  1277212.77   C467632528     1277212.77             0.0
# 1115     1  TRANSFER    35063.63  C1364127192       35063.63             0.0
# 1116     1  CASH_OUT    35063.63  C1635772897       35063.63             0.0
# ...

# %%
df["error_balance_orig"] = df["oldbalanceOrg"] - df["newbalanceOrig"]
df["error_balance_dest"] = df["newbalanceDest"] - df["oldbalanceDest"]

df["is_full_drain"] = ((df["oldbalanceOrg"] > 0) & (df["newbalanceOrig"] == 0)).astype(int)

df["is_new_destination"] = (df["oldbalanceDest"] == 0).astype(int)

df["is_transfer"] = (df["type"] == "TRANSFER").astype(int)
df["is_cashout"] = (df["type"] == "CASH_OUT").astype(int)

df["high_value_txn"] = (df["amount"] > df["amount"].quantile(0.95)).astype(int)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(
    n_estimators=200,
    class_weight="balanced",
    random_state=42,
    n_jobs=-1
)

# %%
from sklearn.model_selection import train_test_split

features = [
    "amount",
    "oldbalanceOrg",
    "newbalanceOrig",
    "oldbalanceDest",
    "newbalanceDest",
    "error_balance_orig",
    "error_balance_dest",
    "is_full_drain",
    "is_new_destination",
    "is_transfer",
    "is_cashout",
    "high_value_txn"
]

X = df[features]
y = df["isFraud"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=200, n_jobs=-1,
#                        random_state=42)

# %%
from sklearn.metrics import classification_report, confusion_matrix

y_pred = model.predict(X_test)

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[209482      5]
#  [    85    143]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    209487
#            1       0.97      0.63      0.76       228
#
#     accuracy                           1.00    209715
#    macro avg       0.98      0.81      0.88    209715
# weighted avg       1.00      1.00      1.00    209715

# %%
import joblib
joblib.dump(model, "model.pkl")
# Out:
# ['model.pkl']
